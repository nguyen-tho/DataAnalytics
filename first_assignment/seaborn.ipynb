# %% [markdown]
# **Cài đặt Seaborn**

# %%
# !pip install seaborn

# %%
from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/data'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Đọc dữ liệu từ tệp CSV bằng Pandas
dataset_path = base_path+ '/youtube_trending/CAvideos.csv'
data = pd.read_csv(dataset_path)

# Hiển thị 5 dòng đầu tiên của dữ liệu để kiểm tra
print(data.head())

# Ví dụ về việc sử dụng Seaborn để tạo biểu đồ
sns.scatterplot(x="views", y="likes", data=data)

# Hiển thị biểu đồ
plt.show()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %% [markdown]
# ##**1. lmplots**

# %%
print(data.dtypes)
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
# Tạo biểu đồ lmplot giữa số lượt xem (views) và số lượt thích (likes)
sns.lmplot(data=data, x='views', y='likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.title('Linear Regression Plot of Views vs Likes')
plt.show()

# %% [markdown]
# Biểu đồ lmplot là một công cụ trực quan được cung cấp bởi thư viện Seaborn trong Python để khám phá mối quan hệ giữa hai biến số và xem xét cách mối quan hệ này có thể thay đổi theo một biến số thứ ba (hoặc nhiều biến số thứ ba khác nhau).
#
# Đặc điểm chính của biểu đồ lmplot là nó kết hợp giữa biểu đồ phân tán (scatter plot) và đường hồi quy tuyến tính (linear regression line), trong đó mỗi điểm trên biểu đồ phân tán biểu thị một quan sát trong dữ liệu và đường hồi quy tuyến tính thể hiện mối quan hệ tuyến tính giữa hai biến.
#
# Biểu đồ lmplot thường được sử dụng để:
#
# Hiểu mối quan hệ giữa hai biến số và xác định liệu có một mối quan hệ tuyến tính giữa chúng hay không.
# Đánh giá sự biến đổi của mối quan hệ này theo một hoặc nhiều biến số thứ ba.
# Phân tích mô hình hồi quy tuyến tính và kiểm tra giả định về mối quan hệ tuyến tính giữa biến độc lập và biến phụ thuộc.
# Biểu đồ lmplot là một công cụ hữu ích trong phân tích dữ liệu và khám phá dữ liệu, giúp làm rõ mối quan hệ giữa các biến số một cách trực quan.

# %% [markdown]
# ##**2. Bar plots**

# %% [markdown]
# Biểu đồ cột (Bar plots) là một công cụ trực quan được sử dụng để hiển thị các giá trị của các biến phân loại thông qua các cột dọc hoặc ngang. Cột đại diện cho mỗi giá trị của biến phân loại và chiều cao hoặc độ dài của cột thể hiện giá trị của biến số liên quan.
#
# Đặc điểm chính của biểu đồ cột:
#
# Biến phân loại: Biểu đồ cột thường được sử dụng để hiển thị phân phối của một biến phân loại (categorical variable). Các cột trên biểu đồ thường biểu thị các nhóm hoặc danh mục khác nhau của biến phân loại đó.
# Biến số: Chiều cao hoặc độ dài của các cột thể hiện giá trị của biến số liên quan. Có thể là tổng hoặc giá trị trung bình của biến số cho mỗi nhóm của biến phân loại.
# Biểu đồ cột thường được sử dụng để:
#
# So sánh giá trị của biến số giữa các nhóm hoặc danh mục của biến phân loại.
# Hiển thị phân phối hoặc tần suất của biến phân loại.
# Trực quan hóa kết quả của các thí nghiệm hoặc nghiên cứu phân loại.
# Biểu đồ cột là một công cụ hữu ích trong phân tích dữ liệu và làm cho dữ liệu trở nên dễ hiểu và trực quan hơn.

# %%
# Tạo biểu đồ cột tổng hợp các biến views, likes, dislikes theo category_id
sns.barplot(data=data, x='category_id', y='views', hue='ratings_disabled', estimator=sum)
plt.xlabel('Category ID')
plt.ylabel('Total')
plt.title('Total Views with Ratings Disabled vs Enabled by Category')
plt.legend(title='Ratings Disabled', labels=['Enabled', 'Disabled'])
plt.show()

# %% [markdown]
# ##**3. Biểu đồ phân phối (Distribution plot)**

# %% [markdown]
# Biểu đồ phân phối (Distribution plot) là một loại biểu đồ được sử dụng để hiển thị phân phối của một biến số. Nó thường được sử dụng để biểu diễn hình dạng của phân phối xác suất của một biến số, cho phép ta nhìn thấy sự phân tán của dữ liệu và xác định các đặc điểm chính như trung bình, phương sai, độ lệch và độ nhọn của phân phối.
#
# Đặc điểm chính của biểu đồ phân phối:
#
# Dữ liệu liên tục: Biểu đồ phân phối thích hợp cho các biến số liên tục, trong đó dữ liệu được đo hoặc đo lường trên một thang đo liên tục.
# Hình dạng phân phối: Biểu đồ phân phối cho phép nhìn thấy hình dạng chung của phân phối dữ liệu, bao gồm độ lệch, độ nhọn và mức độ phân tán.
# Biểu đồ phân phối thường được sử dụng để:
#
# Kiểm tra tính đối xứng của phân phối dữ liệu.
# Phát hiện sự lệch và đuôi dữ liệu.
# Đánh giá các thông số thống kê mô tả như trung bình, phương sai, độ lệch và độ nhọn.
# Trong Python, thư viện Seaborn cung cấp một hàm sns.distplot() để vẽ biểu đồ phân phối. Biểu đồ này thường bao gồm một đường cong ước lượng (estimation curve) của phân phối xác suất cùng với histogram của dữ liệu.

# %%
# Tạo một biểu đồ phân phối của các biến views, likes, dislikes, và comment_count, phân loại theo category_id
sns.pairplot(data=data, vars=['views', 'likes', 'dislikes', 'comment_count'], hue='category_id', diag_kind='kde', palette='Set2')
plt.suptitle('Pairplot of Views, Likes, Dislikes, and Comment Count by Category ID', y=1.02)
plt.show()

# %% [markdown]
# ## **4. Box plots**

# %% [markdown]
# Biểu đồ box plot (Box plot) là một công cụ trực quan được sử dụng để mô tả phân phối của một biến số thông qua các thống kê mô tả cơ bản như median, quartiles và range. Nó cung cấp một cái nhìn tổng quan về phân phối của dữ liệu và giúp xác định các điểm dữ liệu ngoại lệ (outliers).
#
# Đặc điểm chính của biểu đồ box plot:
#
# Median và Quartiles: Hình dạng của hộp (box) trên biểu đồ thể hiện vị trí của median và quartiles (Q1 và Q3) của dữ liệu.
# Whiskers: Dải (whiskers) trên và dưới hộp thể hiện phạm vi của dữ liệu, trong đó các điểm dữ liệu không được coi là outliers.
# Outliers: Các điểm dữ liệu nằm ngoài phạm vi của dải whiskers được hiển thị dưới dạng các điểm hoặc dấu chấm.
# Biểu đồ box plot thường được sử dụng để:
#
# Hiểu được phân phối của dữ liệu và xác định các điểm ngoại lệ.
# So sánh phân phối của một biến số giữa các nhóm hoặc danh mục khác nhau của một biến phân loại.
# Hiển thị sự biến động của dữ liệu và đánh giá sự phân tán.
# Trong Python, bạn có thể sử dụng hàm sns.boxplot() từ thư viện Seaborn để vẽ biểu đồ box plot và trực quan hóa dữ liệu của bạn. Biểu đồ này cung cấp một cái nhìn tổng quan và rõ ràng về phân phối của dữ liệu.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sắp xếp DataFrame theo số lượt xem giảm dần
sorted_data = data.sort_values(by='views', ascending=False)

# Chọn 10 video có số lượt xem cao nhất
top_10_videos = sorted_data.head(10)

# Tạo biểu đồ hộp của số lượt xem cho 10 video có lượt xem cao nhất, phân loại theo 'category_id' và sử dụng màu sắc khác nhau cho 'ratings_disabled'
sns.boxplot(data=top_10_videos, x='category_id', y='views', hue='ratings_disabled', palette='Set2')

# Đặt nhãn và tiêu đề cho biểu đồ
plt.xlabel('Category ID')
plt.ylabel('Views')
plt.title('Box Plot of Views for Top 10 Videos by Category ID with Ratings Disabled')

# Hiển thị chú thích
plt.legend(title='Ratings Disabled', labels=['Enabled', 'Disabled'])

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ## **5.KDE plot**

# %% [markdown]
# KDE plot (Kernel Density Estimation plot) là một loại biểu đồ phân phối được sử dụng để ước lượng hàm mật độ xác suất của một biến số liên tục. Nó giúp hiểu được hình dạng tổng quan của phân phối dữ liệu một cách trực quan và chi tiết.
#
# Đặc điểm chính của KDE plot:
#
# Ước lượng mật độ xác suất: KDE plot ước lượng mật độ xác suất của dữ liệu bằng cách áp dụng một hàm kernel đối với mỗi điểm dữ liệu và kết hợp chúng để tạo ra một ước lượng liên tục về mật độ xác suất trên toàn bộ phạm vi của biến số. Hình dạng phân phối: Biểu đồ KDE plot thể hiện hình dạng tổng quan của phân phối dữ liệu, bao gồm các đặc điểm như đối xứng, lệch và độ nhọn. Mức độ phân tán: Độ rộng của đỉnh và hình dạng của đỉnh trên KDE plot thể hiện mức độ phân tán của dữ liệu. KDE plot thường được sử dụng để:
#
# Hiểu được hình dạng tổng quan của phân phối dữ liệu và các đặc điểm chính của nó như đối xứng, lệch và độ nhọn. So sánh phân phối của một biến số giữa các nhóm hoặc danh mục khác nhau của một biến phân loại. Hiển thị sự biến động của dữ liệu và đánh giá sự phân tán. Trong Python, bạn có thể sử dụng hàm sns.kdeplot() từ thư viện Seaborn để vẽ biểu đồ KDE plot và trực quan hóa dữ liệu của bạn. Biểu đồ này cung cấp một cái nhìn chi tiết và mượt mà về phân phối của dữ liệu.

# %%
# Sắp xếp DataFrame theo số lượt xem giảm dần
sorted_data = data.sort_values(by='views', ascending=False)

# Chọn 10 video có số lượt xem cao nhất
top_10_videos = sorted_data.head(10)

# Tạo KDE plot cho cột 'views' của 10 video có lượt xem cao nhất
sns.kdeplot(data=top_10_videos['views'])

# Đặt nhãn và tiêu đề cho biểu đồ
plt.xlabel('Views')
plt.ylabel('Density')
plt.title('KDE Plot of Views for Top 10 Videos')

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# ## **6. Violin plots**

# %% [markdown]
# Violin plot là một loại biểu đồ sử dụng để hiển thị phân phối của một biến số liên tục hoặc một số lượng biến số dựa trên một biến phân loại. Nó kết hợp giữa box plot và KDE plot để cung cấp một cái nhìn tổng quan và chi tiết về phân phối dữ liệu.
#
# Đặc điểm chính của violin plot:
#
# Phân phối dữ liệu: Violin plot thể hiện phân phối của dữ liệu thông qua một đường cong mật độ xác suất (KDE plot) được chiếu lên hai bên của biến phân loại.
# Median và quartiles: Các đường kẻ ngang trong violin plot thể hiện vị trí của median và quartiles của dữ liệu.
# Phân tán dữ liệu: Độ rộng của violin plot thể hiện phân tán của dữ liệu, với violin plots rộng hơn biểu thị dữ liệu phân tán rộng hơn.
# Violin plot thường được sử dụng để:
#
# Hiểu được phân phối của một biến số hoặc một số lượng biến số theo một biến phân loại.
# So sánh phân phối của các nhóm hoặc danh mục khác nhau của biến phân loại.
# Phát hiện sự biến đổi và độ biến động của dữ liệu.
# Trong Python, bạn có thể sử dụng hàm sns.violinplot() từ thư viện Seaborn để vẽ biểu đồ violin plot và trực quan hóa dữ liệu của bạn. Biểu đồ này cung cấp một cái nhìn tổng quan và chi tiết về phân phối của dữ liệu.

# %%
# Sắp xếp DataFrame theo số lượt xem giảm dần
sorted_data = data.sort_values(by='views', ascending=False)

# Chọn 30 video có số lượt xem cao nhất
top_30_videos = sorted_data.head(30)

# Tạo biểu đồ violin cho cột 'comment_count' của 30 video có lượt xem cao nhất
sns.violinplot(data=top_30_videos['comment_count'])

# Đặt nhãn và tiêu đề cho biểu đồ
plt.xlabel('Comment Count')
plt.title('Violin Plot of Comment Count for Top 30 Videos by Views')

# Hiển thị biểu đồ
plt.show()

# %% [markdown]
# Heat map (bản đồ nhiệt độ) là một loại biểu đồ được sử dụng để hiển thị dữ liệu hai chiều bằng cách sử dụng màu sắc để biểu diễn giá trị của các ô trong một bảng hoặc ma trận. Mỗi ô sẽ có một màu tương ứng với giá trị của nó, cho phép người đọc dễ dàng nhận biết các mẫu và quan hệ trong dữ liệu.
#
# Đặc điểm chính của heat map:
#
# Biểu diễn dữ liệu hai chiều: Heat map thích hợp cho việc biểu diễn dữ liệu hai chiều trong một bảng hoặc ma trận. Mỗi ô trong heat map biểu diễn một cặp giá trị của hai biến số.
# Màu sắc: Heat map sử dụng màu sắc để biểu diễn giá trị của các ô. Các giá trị cao hơn thường được biểu diễn bằng màu sắc tối hơn hoặc màu sáng hơn, tùy thuộc vào màu sắc được chọn.
# Thể hiện mẫu và quan hệ: Heat map cho phép người đọc dễ dàng nhận biết các mẫu và quan hệ trong dữ liệu, bao gồm sự tương quan, tương đồng hoặc chênh lệch giữa các biến số.
# Heat map thường được sử dụng để:
#
# Hiển thị ma trận tương quan hoặc ma trận tương đồng giữa các biến số.
# Biểu diễn dữ liệu trong các nghiên cứu khoa học, kinh doanh hoặc xã hội học.
# Phát hiện các mẫu hoặc quan hệ trong dữ liệu.
# Trong Python, bạn có thể sử dụng các thư viện như Matplotlib hoặc Seaborn để vẽ heat map và trực quan hóa dữ liệu của bạn. Đối với Seaborn, bạn có thể sử dụng hàm sns.heatmap().

# %%
# Loại bỏ các cột không phải dạng số từ DataFrame
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Tính toán ma trận tương quan giữa các biến số
correlation_matrix = numeric_data.corr()

# Vẽ biểu đồ heat map
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heat Map of Correlation Matrix')
plt.show()
